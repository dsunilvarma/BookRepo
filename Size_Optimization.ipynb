# %% [markdown]
# <a href="https://colab.research.google.com/github/dsunilvarma/BookRepo/blob/master/Size_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from itertools import combinations

# Load the data
sales = pd.read_csv('https://raw.githubusercontent.com/ben519/sizecurve/master/sales.csv')
sales
# Out:
#           date variant  sales  depleted
# 0   2021-01-01   small     15     False
# 1   2021-01-01  medium     20     False
# 2   2021-01-01   large     23     False
# 3   2021-01-01      xl     11     False
# 4   2021-01-02   small     73     False
# 5   2021-01-02  medium     99     False
# 6   2021-01-02   large    114     False
# 7   2021-01-02      xl    105     False
# 8   2021-01-03   small      2      True
# 9   2021-01-03  medium     21     False
# 10  2021-01-03   large     20     False
# 11  2021-01-03      xl     15     False

# %%
#=== Solver ============================================================================================
 
def get_size_curve(pairs, alpha = 0.0001, iters = 100):
  """
  Given a dataframe of unique variant pairs (v1, v2) and associated
  pairwise sales (n1, n2), return the most likely size curve
  """
 
  # Copy input dataframe before we muck it up
  pairs2 = pairs.copy()
 
  # Insert total sales
  pairs2['n'] = pairs2.n1 + pairs2.n2
 
  # initialize probabilities for every variant
  variants = pd.DataFrame({'variant': pd.unique(pd.concat((pairs2.v1, pairs2.v2)))})
  variants['p'] = 1/len(variants)
  variants.set_index('variant', inplace=True)
 
  # Gradient ascent
  for i in range(iters):
 
    # Insert probabilities into pairs2
    pairs2.set_index('v1', inplace=True)
    pairs2['p1'] = variants.p
    pairs2.reset_index(inplace=True)
    pairs2.set_index('v2', inplace=True)
    pairs2['p2'] = variants.p
    pairs2.reset_index(inplace=True)
 
    # Calculate log likelihood
    pairs2['p12'] = pairs2.p1/(pairs2.p1 + pairs2.p2)
    pairs2['logl'] = pairs2.n1 * np.log(pairs2.p1) + (pairs2.n - pairs2.n1) * np.log(1 - pairs2.p1)
    logl = np.sum(pairs2.logl)
 
    # Print progress
    print(f'iteration: {i}, log likelihood: {logl}')
 
    # Calculate the gradient (partial log likelihood / partial p_i)
    pairs2['g1'] = (pairs2.n1/pairs2.p12 - (pairs2.n - pairs2.n1)/(1 - pairs2.p12)) * (pairs2.p2)/(pairs2.p1 + pairs2.p2)**2
    pairs2['g2'] = (pairs2.n1/pairs2.p12 - (pairs2.n - pairs2.n1)/(1 - pairs2.p12)) * (-pairs2.p1)/(pairs2.p1 + pairs2.p2)**2
    grads = pd.concat((
        pairs2[['v1', 'g1']].rename(columns={'v1':'variant', 'g1':'grad'}),
        pairs2[['v2', 'g2']].rename(columns={'v2':'variant', 'g2':'grad'})
    ))
    grads = grads.groupby('variant')[['grad']].sum()
 
    # Update probabilities (gradient step)
    variants['grad'] = grads['grad']
    variants['p'] = variants.p + alpha * variants.grad
    variants['p'] = variants.p/variants.p.sum()
 
  return variants[['p']]

# %%
# Generate pairwise data
variants = sales.variant.unique()
variant_pairs = [comb for comb in combinations(variants, 2)]

# For each (v1, v2) pair, count the inventory on days where both v1 and v2 were present,
# and neither was depleted
pairs = []
salesnd = sales.loc[~(sales.depleted)]
for vp in variant_pairs:
  temp = pd.concat((
      salesnd.loc[salesnd.variant == vp[0]],
      salesnd.loc[salesnd.variant == vp[1]]
  ))
  temp['variants'] = temp.groupby('date')['variant'].transform('count')
  temp = temp.loc[temp.variants == 2]
  counts = temp.groupby('variant')['sales'].sum()
  pair = pd.DataFrame({
      'v1': [vp[0]],
      'v2': [vp[1]],
      'n1':[counts.loc[vp[0]]],
      'n2':[counts.loc[vp[1]]]
    })
  pairs.append(pair)

# Combine list of pairs into a singe DataFrame
pairs = pd.concat(pairs)

# %%
sc = get_size_curve(pairs, alpha = 0.0001, iters = 100)
print(sc)
# Out:
# iteration: 0, log likelihood: -1199.348866454402
# iteration: 1, log likelihood: -1201.4131925156612
# iteration: 2, log likelihood: -1205.1679506362093
# iteration: 3, log likelihood: -1208.5507572119607
# iteration: 4, log likelihood: -1210.9185063154166
# iteration: 5, log likelihood: -1212.3528198244578
# iteration: 6, log likelihood: -1213.1498426343644
# iteration: 7, log likelihood: -1213.5715764981671
# iteration: 8, log likelihood: -1213.7892205488747
# iteration: 9, log likelihood: -1213.900481747264
# iteration: 10, log likelihood: -1213.9574453559765
# iteration: 11, log likelihood: -1213.9869158802458
# iteration: 12, log likelihood: -1214.0024489783104
# iteration: 13, log likelihood: -1214.010853248104
# iteration: 14, log likelihood: -1214.0155506835515
# iteration: 15, log likelihood: -1214.0182737041512
# iteration: 16, log likelihood: -1214.019911820108
# iteration: 17, log likelihood: -1214.0209316923942
# iteration: 18, log likelihood: -1214.0215853777577
# iteration: 19, log likelihood: -1214.0220139604176
# iteration: 20, log likelihood: -1214.0222995962608
# iteration: 21, log likelihood: -1214.0224920629307
# iteration: 22, log likelihood: -1214.0226226265322
# iteration: 23, log likelihood: -1214.0227115183761
# iteration: 24, log likelihood: -1214.022772126948
# iteration: 25, log likelihood: -1214.0228134518538
# iteration: 26, log likelihood: -1214.0228416030577
# iteration: 27, log likelihood: -1214.022860752259
# iteration: 28, log likelihood: -1214.022873755241
# iteration: 29, log likelihood: -1214.0228825680854
# iteration: 30, log likelihood: -1214.0228885296333
# iteration: 31, log likelihood: -1214.0228925548577
# iteration: 32, log likelihood: -1214.02289526783
# iteration: 33, log likelihood: -1214.022897093282
# iteration: 34, log likelihood: -1214.0228983196355
# iteration: 35, log likelihood: -1214.0228991423191
# iteration: 36, log likelihood: -1214.0228996934732
# iteration: 37, log likelihood: -1214.0229000622678
# iteration: 38, log likelihood: -1214.022900308766
# iteration: 39, log likelihood: -1214.022900473356
# iteration: 40, log likelihood: -1214.0229005831536
# iteration: 41, log likelihood: -1214.0229006563384
# iteration: 42, log likelihood: -1214.022900705082
# iteration: 43, log likelihood: -1214.0229007375244
# iteration: 44, log likelihood: -1214.0229007591038
# iteration: 45, log likelihood: -1214.0229007734495
# iteration: 46, log likelihood: -1214.0229007829812
# iteration: 47, log likelihood: -1214.0229007893113
# iteration: 48, log likelihood: -1214.0229007935136
# iteration: 49, log likelihood: -1214.0229007963023
# iteration: 50, log likelihood: -1214.022900798152
# iteration: 51, log likelihood: -1214.0229007993787
# iteration: 52, log likelihood: -1214.022900800192
# iteration: 53, log likelihood: -1214.022900800731
# iteration: 54, log likelihood: -1214.022900801088
# iteration: 55, log likelihood: -1214.0229008013246
# iteration: 56, log likelihood: -1214.0229008014815
# iteration: 57, log likelihood: -1214.0229008015851
# iteration: 58, log likelihood: -1214.022900801654
# iteration: 59, log likelihood: -1214.0229008016993
# iteration: 60, log likelihood: -1214.0229008017295
# iteration: 61, log likelihood: -1214.0229008017495
# iteration: 62, log likelihood: -1214.0229008017625
# iteration: 63, log likelihood: -1214.0229008017714
# iteration: 64, log likelihood: -1214.0229008017773
# iteration: 65, log likelihood: -1214.022900801781
# iteration: 66, log likelihood: -1214.0229008017834
# iteration: 67, log likelihood: -1214.022900801785
# iteration: 68, log likelihood: -1214.0229008017861
# iteration: 69, log likelihood: -1214.022900801787
# iteration: 70, log likelihood: -1214.0229008017875
# iteration: 71, log likelihood: -1214.0229008017877
# iteration: 72, log likelihood: -1214.022900801788
# iteration: 73, log likelihood: -1214.022900801788
# iteration: 74, log likelihood: -1214.0229008017882
# iteration: 75, log likelihood: -1214.0229008017882
# iteration: 76, log likelihood: -1214.0229008017884
# iteration: 77, log likelihood: -1214.0229008017884
# iteration: 78, log likelihood: -1214.0229008017884
# iteration: 79, log likelihood: -1214.0229008017886
# iteration: 80, log likelihood: -1214.0229008017886
# iteration: 81, log likelihood: -1214.0229008017886
# iteration: 82, log likelihood: -1214.0229008017886
# iteration: 83, log likelihood: -1214.0229008017886
# iteration: 84, log likelihood: -1214.0229008017886
# iteration: 85, log likelihood: -1214.0229008017886
# iteration: 86, log likelihood: -1214.0229008017886
# iteration: 87, log likelihood: -1214.0229008017886
# iteration: 88, log likelihood: -1214.0229008017886
# iteration: 89, log likelihood: -1214.0229008017886
# iteration: 90, log likelihood: -1214.0229008017886
# iteration: 91, log likelihood: -1214.0229008017886
# iteration: 92, log likelihood: -1214.0229008017886
# iteration: 93, log likelihood: -1214.0229008017886
# iteration: 94, log likelihood: -1214.0229008017886
# iteration: 95, log likelihood: -1214.0229008017886
# iteration: 96, log likelihood: -1214.0229008017886
# iteration: 97, log likelihood: -1214.0229008017886
# iteration: 98, log likelihood: -1214.0229008017886
# iteration: 99, log likelihood: -1214.0229008017886
#                 p
# variant
# small    0.191292
# medium   0.263396
# large    0.296879
# xl       0.248433
